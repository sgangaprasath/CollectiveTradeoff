# %% [markdown]
# # Plots for the article

# %%
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib as mpl
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42

import importlib
# Function for plots
import plotFns as pF
# Parameters in the model
import prmtsLin as pR

# %%
# colors = ["#59283A", "#332859", "#F2A71B", "#F2911B", "#D93829"]

colors = ["#414AF2", "#934ED9", "#4AD96D", "#F2E527", "#F23005"]

# colors = ["#0597F2", "#067302", "#73544D", "#F29F05", "#F20505"]

# %%
importlib.reload(pF)
importlib.reload(pR)

mpl.rcParams.update(mpl.rcParamsDefault)
plt.rc("font", family="SF Pro")
plt.rc("xtick", labelsize="medium")
rc = {"mathtext.fontset" : "cm"}
plt.rcParams.update(rc)
plt.rcParams["font.serif"] = plt.rcParams["font.serif"]

linewidth = 1.0
linestyle = "-"
label_size = 12
color = '#EF6024'

fig = plt.figure(figsize=(4, 3), dpi=300)
nRow = 1
nCol = 1
ax = plt.subplot(nRow, nCol, 1)

p = pR.params()
phiPtn = np.linspace(0, np.pi, p.nPtn+1)

for ind in range(5):
        print(p.pe, p.lNu)
        df1 = pd.read_csv('./plotData/vFullRL_Pe_'+str(p.pe)+'_lNu_'+str(p.lNu)+'.csv')
        df2 = pd.read_csv('./plotData/vFull_Pe_'+str(p.pe)+'_lNu_'+str(p.lNu)+'.csv')
        n = p.nPtn
        phiPlt = np.linspace(0, np.pi, n)
        ax.scatter(phiPlt, df1.iloc[:,2],
                s=30,
                color=colors[ind],
                edgecolors='k',
                linewidth=0.5,
                alpha = 0.9,
                zorder=-1)
        ax.plot(df2.iloc[:, 0], df2.iloc[:, 1],
                color=colors[ind],
                linewidth=linewidth,
                zorder=1)
        ax.plot(df2.iloc[:, 0], df2.iloc[:, 1],
                color="white",
                linewidth=1.5,
                zorder=0)
        p.nu = p.nu*2
        p.pe = p.diff/p.nu #peclet number
        p.lNu = p.vo/p.nu #length-scale used for non-dimensionalization (s)
        

ax.set_xlabel(r'$s_c$',usetex=True, fontsize=label_size+4)
ax.set_ylabel(r'$v_{\rm full}(s_c)$',usetex=True, rotation=90, fontsize=label_size+4)
ax.tick_params(axis='both', which='major', labelsize=label_size)
ax.set_yticks([1, 2, 3])
ax.set_xticks([0, np.pi/2, np.pi])
labels = ['$0$', r'$\pi/2$', r'$\pi$']
ax.set_xticklabels(labels, usetex=True)

ax.xaxis.set_label_coords(0.5,-0.15)
ax.yaxis.set_label_coords(-0.1,0.45)

ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)
ax.spines["left"].set_position(("data", 0))
ax.spines["bottom"].set_position(("data", 0))

# plt.savefig("LinearTheoryComparison.svg", bbox_inches='tight', format='svg')
plt.show()
# Out:
# findfont: Font family 'SF Pro' not found.
# findfont: Font family 'SF Pro' not found.
# findfont: Font family 'SF Pro' not found.
# findfont: Font family 'SF Pro' not found.
# findfont: Font family 'SF Pro' not found.
# findfont: Font family 'SF Pro' not found.
# findfont: Font family 'SF Pro' not found.
# findfont: Font family 'SF Pro' not found.
# findfont: Font family 'SF Pro' not found.
# findfont: Font family 'SF Pro' not found.
# findfont: Font family 'SF Pro' not found.
# 0.2 1.0
# 0.1 0.5
# 0.05 0.25
# 0.025 0.125
# 0.0125 0.0625

# %%
global colorsNw
colorsNw = {
    "gray": {
        0: "#f8f9fa",
        1: "#f1f3f5",
        2: "#e9ecef",
        3: "#dee2e6",
        4: "#ced4da",
        5: "#adb5bd",
        6: "#868e96",
        7: "#495057",
        8: "#343a40",
        9: "#212529",
    },
    "red": {
        0: "#fff5f5",
        1: "#ffe3e3",
        2: "#ffc9c9",
        3: "#ffa8a8",
        4: "#ff8787",
        5: "#ff6b6b",
        6: "#fa5252",
        7: "#f03e3e",
        8: "#e03131",
        9: "#c92a2a",
    },
    "pink": {
        0: "#fff0f6",
        1: "#ffdeeb",
        2: "#fcc2d7",
        3: "#faa2c1",
        4: "#f783ac",
        5: "#f06595",
        6: "#e64980",
        7: "#d6336c",
        8: "#c2255c",
        9: "#a61e4d",
    },
    "grape": {
        0: "#f8f0fc",
        1: "#f3d9fa",
        2: "#eebefa",
        3: "#e599f7",
        4: "#da77f2",
        5: "#cc5de8",
        6: "#be4bdb",
        7: "#ae3ec9",
        8: "#9c36b5",
        9: "#862e9c",
    },
    "violet": {
        0: "#f3f0ff",
        1: "#e5dbff",
        2: "#d0bfff",
        3: "#b197fc",
        4: "#9775fa",
        5: "#845ef7",
        6: "#7950f2",
        7: "#7048e8",
        8: "#6741d9",
        9: "#5f3dc4",
    },
    "indigo": {
        0: "#edf2ff",
        1: "#dbe4ff",
        2: "#bac8ff",
        3: "#91a7ff",
        4: "#748ffc",
        5: "#5c7cfa",
        6: "#4c6ef5",
        7: "#4263eb",
        8: "#3b5bdb",
        9: "#364fc7",
    },
    "blue": {
        0: "#e7f5ff",
        1: "#d0ebff",
        2: "#a5d8ff",
        3: "#74c0fc",
        4: "#4dabf7",
        5: "#339af0",
        6: "#228be6",
        7: "#1c7ed6",
        8: "#1971c2",
        9: "#1864ab",
    },
    "cyan": {
        0: "#e3fafc",
        1: "#c5f6fa",
        2: "#99e9f2",
        3: "#66d9e8",
        4: "#3bc9db",
        5: "#22b8cf",
        6: "#15aabf",
        7: "#1098ad",
        8: "#0c8599",
        9: "#0b7285",
    },
    "teal": {
        0: "#e6fcf5",
        1: "#c3fae8",
        2: "#96f2d7",
        3: "#63e6be",
        4: "#38d9a9",
        5: "#20c997",
        6: "#12b886",
        7: "#0ca678",
        8: "#099268",
        9: "#087f5b",
    },
    "green": {
        0: "#ebfbee",
        1: "#d3f9d8",
        2: "#b2f2bb",
        3: "#8ce99a",
        4: "#69db7c",
        5: "#51cf66",
        6: "#40c057",
        7: "#37b24d",
        8: "#2f9e44",
        9: "#2b8a3e",
    },
    "lime": {
        0: "#f4fce3",
        1: "#e9fac8",
        2: "#d8f5a2",
        3: "#c0eb75",
        4: "#a9e34b",
        5: "#94d82d",
        6: "#82c91e",
        7: "#74b816",
        8: "#66a80f",
        9: "#5c940d",
    },
    "yellow": {
        0: "#fff9db",
        1: "#fff3bf",
        2: "#ffec99",
        3: "#ffe066",
        4: "#ffd43b",
        5: "#fcc419",
        6: "#fab005",
        7: "#f59f00",
        8: "#f08c00",
        9: "#e67700",
    },
    "orange": {
        0: "#fff4e6",
        1: "#ffe8cc",
        2: "#ffd8a8",
        3: "#ffc078",
        4: "#ffa94d",
        5: "#ff922b",
        6: "#fd7e14",
        7: "#f76707",
        8: "#e8590c",
        9: "#d9480f",
    },
    "mixed": {
        0: "#880e4f",
        1: "#1a237e",
        2: "#e65100",
        3: "#004d40",
        4: "#c92a2a",
    },
}

# %%
importlib.reload(pF)
import prmts as pR
importlib.reload(pR)

mpl.rcParams.update(mpl.rcParamsDefault)
plt.rc("font", family="SF Pro")
plt.rc("xtick", labelsize="medium")
rc = {"mathtext.fontset" : "cm"}
plt.rcParams.update(rc)
plt.rcParams["font.serif"] = plt.rcParams["font.serif"]

linewidth = 1.0
linestyle = "-"
label_size = 12
color = '#EF6024'

fig = plt.figure(figsize=(4, 3), dpi=300)
nRow = 1
nCol = 1
ax = plt.subplot(nRow, nCol, 1)

p = pR.params()
phiPtn = np.linspace(0, np.pi, p.nPtn+1)

cInd = 0
for eInd in np.arange(0,p.nEpchs,1000):
        df = pd.read_csv('./plotData/vNL_Pe_'+str(p.pe)+'_lNu_'+str(p.lNu)+'_ind_'+str(eInd)+'.csv')
        n = p.nPtn
        phiPlt = np.linspace(0, np.pi, n)
        ax.step(phiPlt, df.iloc[:,2],
                color=colorsNw['red'][cInd],
                linewidth=linewidth,
                zorder=-1)
        
        # p.nu = p.nu*2
        p.pe = p.diff/p.nu #peclet number
        p.lNu = p.vo/p.nu #length-scale used for non-dimensionalization (s)
        cInd += 1
        

ax.set_xlabel(r'$s_c$',usetex=True, fontsize=label_size+4)
ax.set_ylabel(r'$v_{\rm full}(s_c)$',usetex=True,rotation=90, fontsize=label_size+4)
ax.tick_params(axis='both', which='major', labelsize=label_size)
ax.set_yticks([0.5, 1, 1.5, 2])
ax.set_xticks([0, np.pi/2, np.pi])
labels = ['$0$', r'$\pi/2$', r'$\pi$']
ax.set_xticklabels(labels, usetex=True)

ax.xaxis.set_label_coords(0.5,-0.1)
ax.yaxis.set_label_coords(-0.1,0.45)

ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)
ax.spines["left"].set_position(("data", 0))
ax.spines["bottom"].set_position(("data", 0))

# plt.savefig("NonLinearTDLearn.svg", bbox_inches='tight', format='svg')
plt.show()
# Out:
# findfont: Font family 'SF Pro' not found.
# findfont: Font family ['SF Pro'] not found. Falling back to DejaVu Sans.
# findfont: Font family 'SF Pro' not found.
# findfont: Font family 'SF Pro' not found.
# findfont: Font family 'SF Pro' not found.
# findfont: Font family 'SF Pro' not found.
# findfont: Font family 'SF Pro' not found.
# findfont: Font family 'SF Pro' not found.
# findfont: Font family 'SF Pro' not found.
# findfont: Font family 'SF Pro' not found.
# findfont: Font family 'SF Pro' not found.
# findfont: Font family 'SF Pro' not found.
# findfont: Font family 'SF Pro' not found.
# findfont: Font family 'SF Pro' not found.
# findfont: Font family 'SF Pro' not found.

# %%
importlib.reload(pF)
import prmts as pR
importlib.reload(pR)

mpl.rcParams.update(mpl.rcParamsDefault)
plt.rc("font", family="SF Pro")
plt.rc("xtick", labelsize="medium")
rc = {"mathtext.fontset" : "cm"}
plt.rcParams.update(rc)
plt.rcParams["font.serif"] = plt.rcParams["font.serif"]

linewidth = 1.0
linestyle = "-"
label_size = 12
color = '#EF6024'

fig = plt.figure(figsize=(4, 3), dpi=300)
nRow = 1
nCol = 1
ax = plt.subplot(nRow, nCol, 1)

p = pR.params()
phiPtn = np.linspace(0, np.pi, p.nPtn+1)

cInd = 0
for eInd in np.arange(0,p.nEpchs,100):
        if eInd > 9000:
            df = pd.read_csv('./plotData/rwdNL_Pe_'+str(p.pe)+'_lNu_'+str(p.lNu)+'_ind_'+str(eInd)+'.csv')
            df.iloc[:,2] = df.iloc[:,2].str.get(0)
            ax.step(df.iloc[:,1], df.iloc[:,2],
                    color=colorsNw['red'][cInd],
                    linewidth=linewidth,
                    zorder=-1)
            p.pe = p.diff/p.nu #peclet number
            p.lNu = p.vo/p.nu #length-scale used for non-dimensionalization (s)
            cInd += 1
        

ax.set_xlabel(r'$s_c$',usetex=True, fontsize=label_size+4)
ax.set_ylabel(r'$v_{\rm full}(s_c)$',usetex=True,rotation=90, fontsize=label_size+4)
ax.tick_params(axis='both', which='major', labelsize=label_size)
# ax.set_yticks([0.5, 1, 1.5, 2])
# ax.set_xticks([0, np.pi/2, np.pi])
# labels = ['$0$', r'$\pi/2$', r'$\pi$']
# ax.set_xticklabels(labels, usetex=True)

ax.xaxis.set_label_coords(0.5,-0.1)
ax.yaxis.set_label_coords(-0.1,0.45)

ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)
ax.spines["left"].set_position(("data", 0))
ax.spines["bottom"].set_position(("data", 0))

# plt.savefig("NonLinearTDLearn.svg", bbox_inches='tight', format='svg')
plt.show()
# Out:
# findfont: Font family 'SF Pro' not found.
# findfont: Font family 'SF Pro' not found.
# findfont: Font family 'SF Pro' not found.
# findfont: Font family 'SF Pro' not found.
# findfont: Font family 'SF Pro' not found.
# findfont: Font family 'SF Pro' not found.
# findfont: Font family 'SF Pro' not found.
# findfont: Font family 'SF Pro' not found.
# findfont: Font family 'SF Pro' not found.
# findfont: Font family 'SF Pro' not found.
# findfont: Font family 'SF Pro' not found.
# findfont: Font family 'SF Pro' not found.
# findfont: Font family 'SF Pro' not found.
# findfont: Font family 'SF Pro' not found.
# findfont: Font family 'SF Pro' not found.
# findfont: Font family 'SF Pro' not found.
# findfont: Font family 'SF Pro' not found.
