# %%
import jax
import jax.numpy as jnp
import numpy as np
import matplotlib.pyplot as plt

# %%
xs = np.random.normal(size=(100,))
noise = np.random.normal(scale=0.1, size=(100,))
ys = xs * 3 - 1 + noise

plt.scatter(xs, ys);

# %%
def model(theta, x):
  """Computes wx + b on a batch of input x."""
  w, b = theta
  return w * x + b

def loss_fn(theta, x, y):
  prediction = model(theta, x)
  return jnp.mean((prediction-y)**2)

def update(theta, x, y, lr=0.1):
  return theta - lr * jax.grad(loss_fn)(theta, x, y)

# %%
theta = jnp.array([1., 1.])

for _ in range(1000):
  theta = update(theta, xs, ys)

plt.scatter(xs, ys)
plt.plot(xs, model(theta, xs))

w, b = theta
print(f"w: {w:<.2f}, b: {b:<.2f}")
# Out:
# w: 3.01, b: -1.00

# %%
def hardCore(r):
    eps = 1e-2
    return jnp.where(r>0.2, 0, -1/jnp.exp(r/eps))
    # if r < 0.1:
    #     return 1/jnp.exp(r/eps)
    # else:
    #     return 0

# %%
x = jnp.arange(0,0.5,0.01)
# %timeit hardCore(x).block_until_ready()
plt.plot(x,hardCore(x))
# Out:
# 29 µs ± 201 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
hCore_jit = jax.jit(hardCore)
# Warm up
hCore_jit(x).block_until_ready()

# %timeit hCore_jit(x).block_until_ready()
# Out:
# 4.35 µs ± 31.3 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
plt.plot(x,hardCore(x))

# %%
hCgrad = jax.grad(hardCore)
hCgradVec = jax.vmap(hCgrad)
plt.plot(x,hardCore(x))
plt.plot(x,hCgradVec(x))

# %%
from jax import random

key = random.PRNGKey(42)

print(key)
# Out:
# [ 0 42]

# %%
key, subkey = random.split(key)
print(key)
# Out:
# [3293111712  223174505]

# %%
key = random.PRNGKey(42)
# %timeit x = random.normal(key, shape=(10000,))
plt.hist(x, bins=100)
# Out:
# 419 µs ± 9.27 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# (array([  1.,   0.,   0.,   1.,   1.,   0.,   3.,   6.,   2.,   4.,   8.,
#           3.,  10.,   7.,   9.,  14.,  21.,  19.,  22.,  25.,  33.,  34.,
#          40.,  51.,  56.,  75.,  61.,  91.,  82., 111., 132., 139., 129.,
#         151., 164., 175., 199., 210., 220., 269., 237., 264., 264., 266.,
#         283., 303., 299., 298., 271., 308., 316., 289., 257., 271., 259.,
#         265., 264., 255., 217., 219., 175., 212., 197., 155., 147., 128.,
#         130., 126.,  95.,  83.,  76.,  73.,  61.,  50.,  45.,  43.,  38.,
#          28.,  29.,  25.,  19.,  18.,  20.,   9.,   5.,   4.,   6.,   3.,
#           5.,   1.,   1.,   1.,   2.,   4.,   1.,   0.,   0.,   0.,   0.,
#           2.]),
#  array([-3.69009686, -3.61464262, -3.53918862, -3.46373439, -3.38828039,
#         -3.31282616, -3.23737216, -3.16191792, -3.08646393, -3.01100969,
#         -2.93555546, -2.86010146, -2.78464723, -2.70919323, -2.63373899,
#         -2.558285  , -2.48283076, -2.40737653, -2.33192253, -2.2564683 ,
#         -2.1810143 , -2.10556006, -2.03010607, -1.95465183, -1.87919772,
#         -1.8037436 , -1.72828948, -1.65283537, -1.57738125, -1.50192714,
#         -1.4264729 , -1.35101879, -1.27556467, -1.20011055, -1.12465644,
#         -1.04920232, -0.97374815, -0.89829403, -0.82283992, -0.7473858 ,
#         -0.67193162, -0.59647751, -0.52102339, -0.44556925, -0.37011513,
#         -0.29466099, -0.21920687, -0.14375274, -0.06829861,  0.00715552,
#          0.08260965,  0.15806378,  0.23351792,  0.30897203,  0.38442618,
#          0.45988029,  0.53533441,  0.61078858,  0.6862427 ,  0.76169682,
#          0.83715093,  0.91260511,  0.98805922,  1.0635134 ,  1.13896751,
#          1.21442163,  1.28987575,  1.36532986,  1.44078398,  1.51623809,
#          1.59169221,  1.66714644,  1.74260056,  1.81805468,  1.89350879,
#          1.96896291,  2.04441714,  2.11987114,  2.19532537,  2.27077937,
#          2.34623361,  2.4216876 ,  2.49714184,  2.57259583,  2.64805007,
#          2.7235043 ,  2.7989583 ,  2.87441254,  2.94986653,  3.02532077,
#          3.10077477,  3.176229  ,  3.25168324,  3.32713723,  3.40259147,
#          3.47804546,  3.5534997 ,  3.6289537 ,  3.70440793,  3.77986193,
#          3.85531616]),
#  <BarContainer object of 100 artists>)
